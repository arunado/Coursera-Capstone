# %%
import matplotlib as plt
import pandas as pd
import numpy as np

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_590928f7f599463397dc68aaee279193 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='TGpEV3YR--A7xLNQBKrl0ImR7rQnMoy7bmn4cpb_e3DG',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_590928f7f599463397dc68aaee279193.get_object(Bucket='arunasfirstproject-donotdelete-pr-gw4xfiuqojl49x',Key='Topic_Survey_Assignment (3).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#                    Unnamed: 0  Very interested  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332                  729
# 1  Data Analysis / Statistics             1688                  444
# 2             Data Journalism              429                 1081
# 3          Data Visualization             1340                  734
# 4               Deep Learning             1263                  770
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136

# %%
df_data_1.sort_values(by= ['Very interested'], ascending = False)
# Out:
#                    Unnamed: 0  Very interested  Somewhat interested  \
# 1  Data Analysis / Statistics             1688                  444
# 5            Machine Learning             1629                  477
# 3          Data Visualization             1340                  734
# 0   Big Data (Spark / Hadoop)             1332                  729
# 4               Deep Learning             1263                  770
# 2             Data Journalism              429                 1081
#
#    Not interested
# 1              60
# 5              74
# 3             102
# 0             127
# 4             136
# 2             610

# %%
df_data_1.insert(2, "VIP", 'Very interested')

# %% [markdown]
# #

# %%
df_data_1.head()
# Out:
#                    Unnamed: 0  Very interested              VIP  \
# 0   Big Data (Spark / Hadoop)             1332  Very interested
# 1  Data Analysis / Statistics             1688  Very interested
# 2             Data Journalism              429  Very interested
# 3          Data Visualization             1340  Very interested
# 4               Deep Learning             1263  Very interested
#
#    Somewhat interested  Not interested
# 0                  729             127
# 1                  444              60
# 2                 1081             610
# 3                  734             102
# 4                  770             136

# %%
df_data_1['VIP']= df_data_1['Very interested']

# %%
df_data_1.head()
# Out:
#                    Unnamed: 0  Very interested   VIP  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332  1332                  729
# 1  Data Analysis / Statistics             1688  1688                  444
# 2             Data Journalism              429   429                 1081
# 3          Data Visualization             1340  1340                  734
# 4               Deep Learning             1263  1263                  770
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136

# %%
df_data_1['VIP'] = df_data_1['VIP']/2233

# %%
df_data_1.head()
# Out:
#                    Unnamed: 0  Very interested       VIP  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332  0.596507                  729
# 1  Data Analysis / Statistics             1688  0.755934                  444
# 2             Data Journalism              429  0.192118                 1081
# 3          Data Visualization             1340  0.600090                  734
# 4               Deep Learning             1263  0.565607                  770
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136

# %%
df_data_1['VIP'] = df_data_1['VIP'] * 100

# %%
df_data_1.head()
# Out:
#                    Unnamed: 0  Very interested        VIP  \
# 0   Big Data (Spark / Hadoop)             1332  59.650694
# 1  Data Analysis / Statistics             1688  75.593372
# 2             Data Journalism              429  19.211823
# 3          Data Visualization             1340  60.008957
# 4               Deep Learning             1263  56.560681
#
#    Somewhat interested  Not interested
# 0                  729             127
# 1                  444              60
# 2                 1081             610
# 3                  734             102
# 4                  770             136

# %%
dfint= df_data_1['VIP'].astype(int)

# %%
dfint.head()
# Out:
# 0    59
# 1    75
# 2    19
# 3    60
# 4    56
# Name: VIP, dtype: int64

# %%
df_data_1['SIP']= df_data_1['Somewhat interested']

df_data_1['SIP'] = df_data_1['SIP']/2233
df_data_1['SIP'] = df_data_1['SIP'] * 100

df_data_1['NIP']= df_data_1['Not interested']

df_data_1['NIP'] = df_data_1['NIP']/2233
df_data_1['NIP'] = df_data_1['NIP'] * 100

# %%
df_data_1.head()
# Out:
#                    Unnamed: 0  Very interested        VIP  \
# 0   Big Data (Spark / Hadoop)             1332  59.650694
# 1  Data Analysis / Statistics             1688  75.593372
# 2             Data Journalism              429  19.211823
# 3          Data Visualization             1340  60.008957
# 4               Deep Learning             1263  56.560681
#
#    Somewhat interested  Not interested        SIP        NIP
# 0                  729             127  32.646664   5.687416
# 1                  444              60  19.883565   2.686968
# 2                 1081             610  48.410210  27.317510
# 3                  734             102  32.870578   4.567846
# 4                  770             136  34.482759   6.090461

# %%
pd.astype(df_data_1.VIP, downcast= 'integer')
# Out:
# 0    59.650694
# 1    75.593372
# 2    19.211823
# 3    60.008957
# 4    56.560681
# 5    72.951187
# Name: VIP, dtype: float64

# %%
df_data_1['VIP'] = df_data_1['VIP'].apply(int)
df_data_1['SIP'] = df_data_1['SIP'].apply(int)
df_data_1['NIP'] = df_data_1['NIP'].apply(int)

# %%
df_data_1.head()
# Out:
#                    Unnamed: 0  Very interested  VIP  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332   59                  729
# 1  Data Analysis / Statistics             1688   75                  444
# 2             Data Journalism              429   19                 1081
# 3          Data Visualization             1340   60                  734
# 4               Deep Learning             1263   56                  770
#
#    Not interested  SIP  NIP
# 0             127   32    5
# 1              60   19    2
# 2             610   48   27
# 3             102   32    4
# 4             136   34    6

# %%
df_data_1.sort_values(by= ['Very interested'], ascending = False)
# Out:
#                    Unnamed: 0  Very interested  VIP  Somewhat interested  \
# 1  Data Analysis / Statistics             1688   75                  444
# 5            Machine Learning             1629   72                  477
# 3          Data Visualization             1340   60                  734
# 0   Big Data (Spark / Hadoop)             1332   59                  729
# 4               Deep Learning             1263   56                  770
# 2             Data Journalism              429   19                 1081
#
#    Not interested  SIP  NIP
# 1              60   19    2
# 5              74   21    3
# 3             102   32    4
# 0             127   32    5
# 4             136   34    6
# 2             610   48   27

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['Data Analysis', 'ML', 'DV', 'Bigdata', 'DL', 'DJ']
fontsize = 14
VIP = [76, 72, 60, 59, 56, 19]
SIP = [19, 21, 32, 32, 34, 48]
NIP = [2, 3, 4, 5, 6, 27]

x = np.arange(len(labels))  # the label locations

width = 0.08  # the width of the bars
fig, ax = plt.subplots(figsize=(20,8))

rects1 = ax.bar(x - 0.08, VIP, width, color = '#5cb85c', label='Very Interested')
rects2 = ax.bar(x + 0.01, SIP, width, color = '#5bc0de', label='Somewhat Interested')
rects3 = ax.bar(x + 0.10, NIP, width, color = '#d9534f', label='Not Interested')

# Add some text for labels, title and custom x-axis tick labels, etc.

ax.set_title('Percentage of respondents with interest in data science', fontsize=20)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

for spine in ax.spines:
    ax.spines[spine].set_visible(False)
autolabel(rects1)
autolabel(rects2)
autolabel(rects3)

fig.tight_layout()

plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
index = ['Data Analysis', 'ML', 'DV', 'Bigdata', 'DL', 'DJ']
VIP = [76, 72, 60, 59, 56, 19]
SIP = [19, 21, 32, 32, 34, 48]
NIP = [2, 3, 4, 5, 6, 27]

df = pd.DataFrame({'Very Interested': VIP,
                   'Somewhat Interested': SIP, 'Not Interested': NIP}, index=index)
ax = df.plot.bar(rot=0)

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant',
         'rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)
ax = df.plot.bar(rot=0)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = ax.plot(t, s, lw=2)

ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

ax.set_ylim(-2,2)
plt.show()
