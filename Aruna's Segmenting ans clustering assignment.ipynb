# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
import sys
# !{sys.executable} -m pip install folium

print('Libraries imported.')
# Out:
# ...
# Libraries imported.

# %%
import requests
import lxml.html as lh

url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

     
        
df = pd.read_html(url)

# %%
len(df), type(df)
# Out:
# (3, list)

# %%
df[0].columns
# Out:
# Index(['Postal Code', 'Borough', 'Neighborhood'], dtype='object')

# %%
df[0].drop['Borough'=='Not assigned']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-ff3a70caf28b> in <module>
# ----> 1 df[0].drop['Borough'=='Not assigned']
#
# TypeError: 'method' object is not subscriptable

# %%
df[0].head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned                        NaN
# 1         M2A      Not assigned                        NaN
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
df[0].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3d7d8fbf8c97> in <module>
# ----> 1 df[0].shape
#
# NameError: name 'df' is not defined

# %%
df[0].dropna(inplace= True)

# %%
df[0].shape
# Out:
# (103, 3)

# %%
df[0]
# Out:
#     Postal Code           Borough  \
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# 8           M9A         Etobicoke
# 9           M1B       Scarborough
# 11          M3B        North York
# 12          M4B         East York
# 13          M5B  Downtown Toronto
# 14          M6B        North York
# 17          M9B         Etobicoke
# 18          M1C       Scarborough
# 20          M3C        North York
# 21          M4C         East York
# 22          M5C  Downtown Toronto
# 23          M6C              York
# 26          M9C         Etobicoke
# 27          M1E       Scarborough
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 32          M6E              York
# 36          M1G       Scarborough
# 39          M4G         East York
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# ...

# %%
# now for the next part of the assignment

# %%
import sys
# !{sys.executable} -m pip install Geocoder
# Out:
# ...
#      |████████████████████████████████| 102kB 7.4MB/s ta 0:00:011
# ...

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_590928f7f599463397dc68aaee279193 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='TGpEV3YR--A7xLNQBKrl0ImR7rQnMoy7bmn4cpb_e3DG',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_590928f7f599463397dc68aaee279193.get_object(Bucket='arunasfirstproject-donotdelete-pr-gw4xfiuqojl49x',Key='Geospatial_Coordinates (2).csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
dfm = pd.merge(df[0],df_data_1, on=['Postal Code'])

# %%
dfm
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %%
#Match postal code to get the Lattitude and longitude, Using the Merge function.!

# %%
import sys
# !{sys.executable} -m pip install folium

# %%
import folium
print(folium.__version__)
# Out:
# 0.5.0

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(dfm['Borough'].unique()),
     dfm.shape[0]
    )
)
# Out:
# The dataframe has 10 boroughs and 103 neighborhoods.

# %%
m = folium.Map(location=[43, -79], zoom_start = 8)



# add markers to map
for lat, lng, label in zip(dfm['Latitude'], dfm['Longitude'], dfm['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(m)  
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.choropleth(geo_data=m, data=dfm,
             columns=['Borough', 'Neighborhood'],
             fill_color='YlGn', fill_opacity=0.7, line_opacity=0.2,
             legend_name='Toronto neighborhoods')
m
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-6a4d602c4551> in <module>
# ----> 1 folium.choropleth(geo_data=m, data=dfm,
#       2              columns=['Borough', 'Neighborhood'],
#       3              fill_color='YlGn', fill_opacity=0.7, line_opacity=0.2,
#       4              legend_name='Participation Rate (%)')
#       5 m
#
# AttributeError: module 'folium' has no attribute 'choropleth'

# %%
dfm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-3ee69eb8fe72> in <module>
# ----> 1 dfm:latitude
#
# NameError: name 'latitude' is not defined

# %%
m = folium.Map(location=[43, -79], Zoom_start= 3)


folium.Choropleth(
    geo_data = m,
    data = dfm,
    columns=['Borough', 'Neighborhood'],
    fill_color='YlGn',
  
    legend_name='Unemployment Rate (%)',
  
).add_to(m)


    
m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-7d7d060c12d1> in <module>
#       9     fill_color='YlGn',
#      10
# ---> 11     legend_name='Unemployment Rate (%)',
#      12
#      13 ).add_to(m)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1249                 style_function=style_function,
#    1250                 smooth_factor=smooth_factor,
# -> 1251                 highlight_function=highlight_function if highlight else None)
#    1252
#    1253         self.add_child(self.geojson)
#
# ...

# %%
 m = folium.Map(
    location=[43.7, -79.5],
    zoom_start=12,
    tiles='Stamen Terrain'
)

folium.Marker(
    location=[43.7, -79.5],
    popup='aruna house',
    icon=folium.Icon(icon='cloud')
).add_to(m)

folium.CircleMarker(
    location=[43.71, -79.49],
    radius=50,
    popup='hyde park',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[43, -79], Zoom_start= 3)


folium.Choropleth(
    geo_data = 'http://geogratis.gc.ca/services/geoname/en/geonames.json?q=toronto',

).add_to(m)


    
m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-7790f06fb81e> in <module>
#       4
#       5 folium.Choropleth(
# ----> 6     geo_data = 'http://geogratis.gc.ca/services/geoname/en/geonames.json?q=toronto',
#       7
#       8 ).add_to(m)
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/folium/features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1249                 style_function=style_function,
#    1250                 smooth_factor=smooth_factor,
# -> 1251                 highlight_function=highlight_function if highlight else None)
#    1252
#    1253         self.add_child(self.geojson)
#
# ...

# %%
print(type(choropleth.geojson))
print(type(choropleth.color_scale))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-3bdb946a343f> in <module>
# ----> 1 print(type(choropleth.geojson))
#       2 print(type(choropleth.color_scale))
#
# NameError: name 'choropleth' is not defined

# %%
folium.Map(
    location=[43, -79],
    tiles='Stamen Toner',
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[43, -79], Zoom_start= 15)


tooltip = 'Click me!'

folium.Marker([44, -85], popup='<i>Mt. Hood Meadows</i>', tooltip=tooltip).add_to(m)
folium.Marker([50, -60], popup='<b>Timberline Lodge</b>', tooltip=tooltip).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.CircleMarker(
    location=[73, -90],
    radius=50,
    popup='Laurelhurst Park',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
