# %%
# Import pandas library
import pandas as pd

# Read the online file by the URL provides above, and assign it to variable "df"
other_path = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv"
df = pd.read_csv(other_path, header=None)

other_path ='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/coursera/project/kc_house_data_NaN.csv'

df=pd.read_csv(other_path)

# %%
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'price', 'bedrooms', 'bathrooms',
#        'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
#        'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0', 'id'], axis=1)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000   221900.0       3.0       1.00         1180      5650
# 1      20141209T000000   538000.0       3.0       2.25         2570      7242
# 2      20150225T000000   180000.0       2.0       1.00          770     10000
# 3      20141209T000000   604000.0       4.0       3.00         1960      5000
# 4      20150218T000000   510000.0       3.0       2.00         1680      8080
# 5      20140512T000000  1225000.0       4.0       4.50         5420    101930
# 6      20140627T000000   257500.0       3.0       2.25         1715      6819
# 7      20150115T000000   291850.0       3.0       1.50         1060      9711
# 8      20150415T000000   229500.0       3.0       1.00         1780      7470
# 9      20150312T000000   323000.0       3.0       2.50         1890      6560
# 10     20150403T000000   662500.0       3.0       2.50         3560      9796
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Unnamed: 0          id             date      price  bedrooms  \
# 0               0  7129300520  20141013T000000   221900.0       3.0
# 1               1  6414100192  20141209T000000   538000.0       3.0
# 2               2  5631500400  20150225T000000   180000.0       2.0
# 3               3  2487200875  20141209T000000   604000.0       4.0
# 4               4  1954400510  20150218T000000   510000.0       3.0
# 5               5  7237550310  20140512T000000  1225000.0       4.0
# 6               6  1321400060  20140627T000000   257500.0       3.0
# 7               7  2008000270  20150115T000000   291850.0       3.0
# 8               8  2414600126  20150415T000000   229500.0       3.0
# 9               9  3793500160  20150312T000000   323000.0       3.0
# 10             10  1736800520  20150403T000000   662500.0       3.0
# 11             11  9212900260  20140527T000000   468000.0       2.0
# ...

# %%
df.describe(include='all')
# Out:
#          Unnamed: 0            id             date         price  \
# count   21613.00000  2.161300e+04            21613  2.161300e+04
# unique          NaN           NaN              372           NaN
# top             NaN           NaN  20140623T000000           NaN
# freq            NaN           NaN              142           NaN
# mean    10806.00000  4.580302e+09              NaN  5.400881e+05
# std      6239.28002  2.876566e+09              NaN  3.671272e+05
# min         0.00000  1.000102e+06              NaN  7.500000e+04
# 25%      5403.00000  2.123049e+09              NaN  3.219500e+05
# 50%     10806.00000  3.904930e+09              NaN  4.500000e+05
# 75%     16209.00000  7.308900e+09              NaN  6.450000e+05
# max     21612.00000  9.900000e+09              NaN  7.700000e+06
#
#             bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count   21600.000000  21603.000000  21613.000000  2.161300e+04  21613.000000
# ...

# %%
df.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-986e25863b45> in <module>
# ----> 1 df.value_counts()
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
dfn = df['floors'].value_counts()

# %%
dfn.to_frame
# Out:
# <bound method Series.to_frame of 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64>

# %%
import seaborn as sns
sns.set(style="whitegrid")

ax = sns.boxplot(x=df['waterfront'], y=df['price'])

# %%
ax = sns.regplot(x=df['sqft_above'], y=df['price'])

# %%
y_data = df['price']
x_data=df.drop('price',axis=1)

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 4323
# number of training samples: 17290

# %%
from sklearn.linear_model import LinearRegression
lre=LinearRegression()

# %%
lre.fit(x_train[['sqft_living']], y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lre.score(x_test[['sqft_living']], y_test)
# Out:
# 0.5033019006466928

# %%
lre.score(x_train[['sqft_living']], y_train)
# Out:
# 0.4887607821388749

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
lre.fit(x_train[['sqft_living', 'floors', 'waterfront', 'sqft_above', 'lat', 'grade', 'view','sqft_basement', 'sqft_living15']], y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lre.score(x_test[['sqft_living', 'floors', 'waterfront', 'sqft_above', 'lat', 'grade', 'view','sqft_basement', 'sqft_living15']], y_test)
# Out:
# 0.6413105771334249

# %%
lre.score(x_train[['sqft_living', 'floors', 'waterfront', 'sqft_above', 'lat', 'grade', 'view','sqft_basement', 'sqft_living15']], y_train)
# Out:
# 0.6584110962133178

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
yhat_train = lre.predict(x_train[['sqft_living', 'floors', 'waterfront', 'sqft_above', 'lat', 'grade', 'view','sqft_basement', 'sqft_living15']])
yhat_train[0:5]
# Out:
# array([589953.25894931, 725375.11239175, 419291.97826758, 748735.00158486,
#        340267.87735327])

# %%
yhat_test = lre.predict(x_test[['sqft_living', 'floors', 'waterfront', 'sqft_above', 'lat', 'grade', 'view','sqft_basement', 'sqft_living15']])
yhat_test[0:5]
# Out:
# array([654328.22145455, 516406.23112576, 772851.59883231, 720558.9017226 ,
#        212147.16115832])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr = PolynomialFeatures(degree=5)
x_train_pr = pr.fit_transform(x_train[['sqft_living', 'floors', 'waterfront', 'sqft_above', 'lat', 'grade', 'view','sqft_basement', 'sqft_living15']])
x_test_pr = pr.fit_transform(x_test[['sqft_living', 'floors', 'waterfront', 'sqft_above', 'lat', 'grade', 'view','sqft_basement', 'sqft_living15']])
pr
# Out:
# PolynomialFeatures(degree=5, include_bias=True, interaction_only=False)

# %%
poly = LinearRegression()
poly.fit(x_train_pr, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
yhat = poly.predict(x_test_pr)
yhat[0:5]
# Out:
# array([ 566656.61492192,  442304.61492192, 1655256.61492192,
#         656644.61492192,  304445.23992192])

# %%
print("Predicted values:", yhat[0:4])
print("True values:", y_test[0:4].values)
# Out:
# Predicted values: [ 566656.61492192  442304.61492192 1655256.61492192  656644.61492192]
# True values: [ 459000.  445000. 1057000.  732350.]

# %%
poly.score(x_train_pr, y_train)
# Out:
# 0.7135710381665977

# %%
poly.score(x_test_pr, y_test)
# Out:
# -1592.8820667984983

# %%
pr=PolynomialFeatures(degree=2)
x_train_pr=pr.fit_transform(x_train[['sqft_living', 'floors', 'waterfront', 'sqft_above', 'lat', 'grade', 'view','sqft_basement', 'sqft_living15']])
x_test_pr=pr.fit_transform(x_test[['sqft_living', 'floors', 'waterfront', 'sqft_above', 'lat', 'grade', 'view','sqft_basement', 'sqft_living15']])

# %%
from sklearn.linear_model import Ridge

# %%
RigeModel=Ridge(alpha=0.1)

# %%
RigeModel.fit(x_test_pr, y_test)
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
RigeModel.score(x_test_pr, y_test)
# Out:
# 0.7634497863008509

# %%
RigeModel.fit(x_train_pr, y_train)
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
RigeModel.score(x_train_pr, y_train)
# Out:
# 0.7289489097739552
